# %%
import pandas as pd 
import requests

# %%
url = 'http://ddragon.leagueoflegends.com/cdn/13.8.1/data/ko_KR/summoner.json'
url2 = 'http://ddragon.leagueoflegends.com/cdn/13.8.1/img/spell/SummonerFlash.png'
url3 = 'http://ddragon.leagueoflegends.com/cdn/13.8.1/img/sprite/spell0.png'

# %%
url = 'http://ddragon.leagueoflegends.com/cdn/13.8.1/data/ko_KR/summoner.json'
def spell(url):
    df_origin = requests.get(url).json()
    df_keys = list(df_origin['data'].keys())
    
    df_spell = []
    for i in df_keys :
        lst = []
        lst.append(df['data'][i]['key'])
        lst.append(df['data'][i]['id'])
        lst.append(df['data'][i]['name'])
        lst.append(df['data'][i]['description'])
        lst.append('http://ddragon.leagueoflegends.com/cdn/13.8.1/img/spell/'+i+'.png')
        
        df_spell.append(lst)
    
    col = ['spell_id','spell_key','spell_name','spell_desc','spell_icon']
    df_spells = pd.DataFrame(df_spell, columns = col)
    return df_spells

# %%
df1 = spell(url)
df1
# Out:
#    spell_id                         spell_key   spell_name  \
# 0        21                   SummonerBarrier          방어막
# 1         1                     SummonerBoost           정화
# 2        14                       SummonerDot           점화
# 3         3                   SummonerExhaust           탈진
# 4         4                     SummonerFlash           점멸
# 5         6                     SummonerHaste          유체화
# 6         7                      SummonerHeal           회복
# 7        13                      SummonerMana           총명
# 8        30                SummonerPoroRecall       왕을 향해!
# 9        31                 SummonerPoroThrow       포로 던지기
# 10       11                     SummonerSmite           강타
# 11       39      SummonerSnowURFSnowball_Mark           표식
# 12       32                  SummonerSnowball           표식
# 13       12                  SummonerTeleport         순간이동
# 14       54       Summoner_UltBookPlaceholder   게임 시작 후 결정
# 15       55  Summoner_UltBookSmitePlaceholder  TBD 및 공격-강타
#
#                                            spell_desc  \
# 0   2초 동안 방어막으로 감싸 피해를 105~411(챔피언 레벨에 따라 변동)만큼 흡수...
# 1   챔피언에 걸린 모든 이동 불가와 (제압 및 공중으로 띄우는 효과 제외) 소환사 주문...
# 2   적 챔피언을 불태워 5초 동안 70~410의 고정 피해(챔피언 레벨에 따라 변동)를...
# 3   적 챔피언을 지치게 만들어 3초 동안 이동 속도를 30% 느리게 하고 이 동안 가하...
# 4                        커서 방향으로 챔피언이 짧은 거리를 순간이동합니다.
# 5   챔피언이 10초 동안 유닛과 충돌하지 않게 되며 챔피언 레벨에 따라 이동 속도가 2...
# 6   자신과 대상 아군 챔피언의 체력을 80~318만큼 (챔피언 레벨에 따라 변동) 회복...
# 7      최대 마나량의 50%를 회복합니다. 주변 아군도 최대 마나량의 25%가 회복됩니다.
# 8                                포로 왕의 곁으로 빠르게 이동합니다.
# 9         포로를 적에게 던집니다. 적이 맞으면 해당 적에게 빠르게 이동할 수 있습니다.
# 10            대상 몬스터 또는 미니언에게 600~1,200의 고정 피해를 입힙니다.
# 11  적을 향해 직선으로 눈덩이를 던집니다. 눈덩이가 적을 맞히면 표식이 남아 절대 시야...
# 12  적을 향해 직선으로 눈덩이를 던집니다. 눈덩이가 적을 맞히면 표식이 남아 절대 시야...
# 13  4초 동안 정신을 집중한 다음, 대상으로 지정한 아군 구조물로 순간이동합니다. 14...
# 14  이 슬롯은 게임 시작 시 선택한 다른 챔피언의 궁극기로 대체됩니다. 궁극기 선택 시...
# 15  이 슬롯은 다른 챔피언의 궁극기로 대체되며 공격-강타 또한 획득합니다. 궁극기 선택...
#
#                                            spell_icon
# 0   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 1   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 2   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 3   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 4   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 5   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 6   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 7   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 8   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 9   http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 10  http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 11  http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 12  http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 13  http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 14  http://ddragon.leagueoflegends.com/cdn/13.8.1/...
# 15  http://ddragon.leagueoflegends.com/cdn/13.8.1/...
